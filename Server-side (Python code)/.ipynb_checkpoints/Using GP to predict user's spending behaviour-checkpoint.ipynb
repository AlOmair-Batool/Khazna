# %%
import gpflow
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from gpflow.utilities import print_summary
import pandas as pd
import numpy as np
from datetime import datetime
import time
from firebase_admin import credentials
from firebase_admin import firestore
import firebase_admin
import pandas as pd
import json
# The lines below are specific to the notebook format
# %matplotlib inline
plt.rcParams["figure.figsize"] = (12, 6)

# %% [markdown]
# ## Read the data from the firebase

# %%
firebase_admin.initialize_app(credential=None, options=None, name='[DEFAULT]')

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="sim1-ac95f-firebase-adminsdk-3hy48-80b6b88451.json"
cred = r"sim1-ac95f-firebase-adminsdk-3hy48-80b6b88451.json"
login = credentials.Certificate(cred)

# %%
db = firestore.client()
transaction = db.collection("transaction").stream()

# %%
dict_users = {"userid":[],"type":[], "amount":[],"time":[],"date":[]}
# data_items = data_dict.items()
# data_list = list(data_items)

count=0
for trans in transaction:
#     print(json.loads("{}".format(trans.to_dict())))
    us = json.loads(str(trans.to_dict()).replace("'",'"').replace(" ","").lower())
    #print(us)
    dict_users["userid"].append(us["userid"])
    dict_users["type"].append(us["type"])
    dict_users["amount"].append(us["amount"])
    dict_users["time"].append(us["time"])
    dict_users["date"].append(us["date"])

# %%
df = pd.DataFrame.from_dict(dict_users)
df["date"] = pd.to_datetime(df['date']+" "+df["time"],errors='coerce')
df["amount"] = df["amount"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userid  44 non-null     object
#  1   type    44 non-null     object
#  2   amount  44 non-null     float64
#  3   time    44 non-null     object
#  4   date    44 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 1.8+ KB

# %% [markdown]
# ## Hnadling outliers

# %%
df = df.drop(df[(df.amount >= 1000)].index).reset_index()
df
# Out:
#     index                userid        type  amount   time                date
# 0       1  0ii5ylqmcwoaas954eev     deposit   139.0  12:18 2022-03-02 12:18:00
# 1       2  1bnpmtnjyjxquotmtbxq  withdrawal   229.0  17:33 2022-09-02 17:33:00
# 2       3  1saxzqezoilxufbrqsg9  withdrawal   204.0  19:06 2022-11-02 19:06:00
# 3       6  2hyvonwoo2pdrfg0bn4m  withdrawal   300.0  18:35 2022-02-14 18:35:00
# 4       7  4ci4eteyuim5x5iwl851  withdrawal    12.0  11:54 2022-02-15 11:54:00
# 5       8  4fnax55emo2207smilll  withdrawal   400.0  17:55 2022-02-19 17:55:00
# 6       9  4pi98iccpijq78kkeu6y  withdrawal   700.0  19:20 2022-02-19 19:20:00
# 7      10  5ziptc8f7a2b0ghb6hwy  withdrawal   250.0  17:50 2022-02-21 17:50:00
# 8      11  6z7ejgoxq3hbnmbhmws7  withdrawal    91.0  23:47 2022-02-21 23:47:00
# 9      12  7bzasnovlhoeoln1cyxo  withdrawal   344.0  18:54 2022-02-22 18:54:00
# 10     13  7d2jsrqohnrlyc8dzm5d     deposit    91.0  19:29 2022-02-26 19:29:00
# 11     14  7qdh8jausi4dhvv0g4bu  withdrawal     2.0  08:41 2022-02-27 08:41:00
# 12     15  7tbph5old7zvjsr1tq6h  withdrawal    15.0  09:48 2022-02-27 09:48:00
# 13     16  804wq8admos1wzxvzbf7  withdrawal    12.0  13:57 2022-02-28 13:57:00
# 14     17  8bjbvzqkdschmhafqrb9  withdrawal    15.0  14:07 2022-02-28 14:07:00
# 15     18  9yqfnhwby290fr4yfgiq     deposit   849.0  19:24 2022-02-28 19:24:00
# 16     19  aa44h0tmbkksclrvxuoo     deposit   344.0  23:39 2022-02-28 23:39:00
# 17     20  agyoegwdftu61kvn1x88  withdrawal    17.0  11:23 2022-06-03 11:23:00
# 18     21  bdl0wlua5huvxlivu9lv  withdrawal    50.0  17:00 2022-08-03 17:00:00
# 19     22  bpbq0lxf6rctrtwzzg97  withdrawal   300.0  17:14 2022-09-03 17:14:00
# 20     23  cnxerxcvyf6es8elsqpu  withdrawal   200.0  20:26 2022-10-03 20:26:00
# 21     24  cr74ablhhlom0o8d9ivo  withdrawal   200.0  21:26 2022-10-03 21:26:00
# 22     25  ctppmjpdx45dztevtt1a  withdrawal    24.0  17:10 2022-12-03 17:10:00
# 23     26  cyjuhdhfezqjaiwjmzbk     deposit     1.0  15:29 2022-03-13 15:29:00
# 24     27  cl2ukpprxx7mbnwki4s6  withdrawal    39.0  21:48 2022-03-14 21:48:00
# 25     28  ct6egkoperwnf34mwwpy  withdrawal    67.0  23:31 2022-03-14 23:31:00
# 26     29  dreo9qyyq1kdwisb35bc  withdrawal   129.0  11:26 2022-03-14 11:26:00
# 27     30  dhbuzjs1auhwmkbvc5cm  withdrawal   110.0  22:17 2022-03-15 22:17:00
# 28     31  dqr23tqkfza8uh3gzize  withdrawal   111.0  22:18 2022-03-15 22:18:00
# 29     32  ejk92mdyu0dltugyjr4e  withdrawal   150.0  17:51 2022-03-19 17:51:00
# 30     33  els1znaovwhofpsugro1  withdrawal     2.0  09:06 2022-03-20 09:06:00
# 31     34  eucfxi1vsdgykkgcmroq  withdrawal   175.0  17:38 2022-03-21 17:38:00
# 32     35  f0kz9z6vbzrqtxp1mfgf  withdrawal   110.0  21:08 2022-03-22 21:08:00
# 33     38  g7pvl278t72gwcr5x2p1  withdrawal    46.0  22:20 2022-03-25 22:20:00
# 34     39  gjpaqfzn0ufo5qbilfwp  withdrawal    12.0  15:58 2022-03-26 15:58:00
# 35     40  gkopuhoulekc3xn7xxqd  withdrawal    10.0  16:13 2022-03-26 16:13:00
# 36     41  ghknlh9m7bxox0un7miv  withdrawal    64.0  12:02 2022-03-27 12:02:00
# 37     42  goyh6oyyn0e48hb6l1gm  withdrawal    13.0  15:30 2022-03-28 15:30:00
# 38     43  gxrqgst2cifwcxb2utdy  withdrawal    50.0  14:15 2022-03-31 14:15:00

# %%
#suggsted appraoch converting to unix timestamp
df["unix_date"] = [datetime.timestamp(dt)/3600 for dt in df["date"]]
df["unix_date"] =tf.cast(df["unix_date"] , tf.float64)
X = df[["unix_date"]]
X = tf.cast(X, tf.float64)

# %%
df['amount'] = tf.cast(df['amount'], tf.float64)
condition = df["type"] == 'withdrawal'
df.loc[condition, ['amount']] *= -1
Y = df[['amount']]
Y = tf.cast(Y, tf.float64)

# %%
#Create a mapping date for example if the date was 24/04/2022 the day26 that should be mapped to 26/04/2020
#27/04/2020 the day26 that should be mapped is 26/05/2020
#this will help us in creating the X_test see the cell bellow were I created X_test
def get_day_26_mapping(date):
    import datetime
    new_date = []
    for m,d,y in zip(date.dt.month,date.dt.day,date.dt.year):
        #print(m,d,y)
        new_d = 0
        new_m = 0
        new_y = 0
        if d<=26:
            new_d = 26
            new_m = m
            new_y = y
        else:
            new_d = 26
            if m+1>12:
                new_d = 26
                new_m = 1
                new_y = y + 1
            else:
                new_d = 26
                new_m = m + 1
                new_y = y
        new_date.append(datetime.datetime(new_y,new_m,new_d))
    return new_date

df['day_26_mapping_date'] = get_day_26_mapping(df['date'])
df
# Out:
#     index                userid        type  amount   time  \
# 0       1  0ii5ylqmcwoaas954eev     deposit   139.0  12:18
# 1       2  1bnpmtnjyjxquotmtbxq  withdrawal  -229.0  17:33
# 2       3  1saxzqezoilxufbrqsg9  withdrawal  -204.0  19:06
# 3       6  2hyvonwoo2pdrfg0bn4m  withdrawal  -300.0  18:35
# 4       7  4ci4eteyuim5x5iwl851  withdrawal   -12.0  11:54
# 5       8  4fnax55emo2207smilll  withdrawal  -400.0  17:55
# 6       9  4pi98iccpijq78kkeu6y  withdrawal  -700.0  19:20
# 7      10  5ziptc8f7a2b0ghb6hwy  withdrawal  -250.0  17:50
# 8      11  6z7ejgoxq3hbnmbhmws7  withdrawal   -91.0  23:47
# 9      12  7bzasnovlhoeoln1cyxo  withdrawal  -344.0  18:54
# 10     13  7d2jsrqohnrlyc8dzm5d     deposit    91.0  19:29
# 11     14  7qdh8jausi4dhvv0g4bu  withdrawal    -2.0  08:41
# 12     15  7tbph5old7zvjsr1tq6h  withdrawal   -15.0  09:48
# 13     16  804wq8admos1wzxvzbf7  withdrawal   -12.0  13:57
# 14     17  8bjbvzqkdschmhafqrb9  withdrawal   -15.0  14:07
# 15     18  9yqfnhwby290fr4yfgiq     deposit   849.0  19:24
# 16     19  aa44h0tmbkksclrvxuoo     deposit   344.0  23:39
# 17     20  agyoegwdftu61kvn1x88  withdrawal   -17.0  11:23
# 18     21  bdl0wlua5huvxlivu9lv  withdrawal   -50.0  17:00
# 19     22  bpbq0lxf6rctrtwzzg97  withdrawal  -300.0  17:14
# 20     23  cnxerxcvyf6es8elsqpu  withdrawal  -200.0  20:26
# 21     24  cr74ablhhlom0o8d9ivo  withdrawal  -200.0  21:26
# 22     25  ctppmjpdx45dztevtt1a  withdrawal   -24.0  17:10
# 23     26  cyjuhdhfezqjaiwjmzbk     deposit     1.0  15:29
# 24     27  cl2ukpprxx7mbnwki4s6  withdrawal   -39.0  21:48
# 25     28  ct6egkoperwnf34mwwpy  withdrawal   -67.0  23:31
# 26     29  dreo9qyyq1kdwisb35bc  withdrawal  -129.0  11:26
# 27     30  dhbuzjs1auhwmkbvc5cm  withdrawal  -110.0  22:17
# 28     31  dqr23tqkfza8uh3gzize  withdrawal  -111.0  22:18
# 29     32  ejk92mdyu0dltugyjr4e  withdrawal  -150.0  17:51
# 30     33  els1znaovwhofpsugro1  withdrawal    -2.0  09:06
# 31     34  eucfxi1vsdgykkgcmroq  withdrawal  -175.0  17:38
# 32     35  f0kz9z6vbzrqtxp1mfgf  withdrawal  -110.0  21:08
# 33     38  g7pvl278t72gwcr5x2p1  withdrawal   -46.0  22:20
# 34     39  gjpaqfzn0ufo5qbilfwp  withdrawal   -12.0  15:58
# 35     40  gkopuhoulekc3xn7xxqd  withdrawal   -10.0  16:13
# 36     41  ghknlh9m7bxox0un7miv  withdrawal   -64.0  12:02
# 37     42  goyh6oyyn0e48hb6l1gm  withdrawal   -13.0  15:30
# 38     43  gxrqgst2cifwcxb2utdy  withdrawal   -50.0  14:15
#
#                   date      unix_date day_26_mapping_date
# 0  2022-03-02 12:18:00  457281.300000          2022-03-26
# 1  2022-09-02 17:33:00  461702.550000          2022-09-26
# 2  2022-11-02 19:06:00  463168.100000          2022-11-26
# 3  2022-02-14 18:35:00  456903.583333          2022-02-26
# 4  2022-02-15 11:54:00  456920.900000          2022-02-26
# 5  2022-02-19 17:55:00  457022.916667          2022-02-26
# 6  2022-02-19 19:20:00  457024.333333          2022-02-26
# 7  2022-02-21 17:50:00  457070.833333          2022-02-26
# 8  2022-02-21 23:47:00  457076.783333          2022-02-26
# 9  2022-02-22 18:54:00  457095.900000          2022-02-26
# 10 2022-02-26 19:29:00  457192.483333          2022-02-26
# 11 2022-02-27 08:41:00  457205.683333          2022-03-26
# 12 2022-02-27 09:48:00  457206.800000          2022-03-26
# 13 2022-02-28 13:57:00  457234.950000          2022-03-26
# 14 2022-02-28 14:07:00  457235.116667          2022-03-26
# 15 2022-02-28 19:24:00  457240.400000          2022-03-26
# 16 2022-02-28 23:39:00  457244.650000          2022-03-26
# 17 2022-06-03 11:23:00  459512.383333          2022-06-26
# 18 2022-08-03 17:00:00  460982.000000          2022-08-26
# 19 2022-09-03 17:14:00  461726.233333          2022-09-26
# 20 2022-10-03 20:26:00  462449.433333          2022-10-26
# 21 2022-10-03 21:26:00  462450.433333          2022-10-26
# 22 2022-12-03 17:10:00  463910.166667          2022-12-26
# 23 2022-03-13 15:29:00  457548.483333          2022-03-26
# 24 2022-03-14 21:48:00  457578.800000          2022-03-26
# 25 2022-03-14 23:31:00  457580.516667          2022-03-26
# 26 2022-03-14 11:26:00  457568.433333          2022-03-26
# 27 2022-03-15 22:17:00  457603.283333          2022-03-26
# 28 2022-03-15 22:18:00  457603.300000          2022-03-26
# 29 2022-03-19 17:51:00  457694.850000          2022-03-26
# 30 2022-03-20 09:06:00  457710.100000          2022-03-26
# 31 2022-03-21 17:38:00  457742.633333          2022-03-26
# 32 2022-03-22 21:08:00  457770.133333          2022-03-26
# 33 2022-03-25 22:20:00  457843.333333          2022-03-26
# 34 2022-03-26 15:58:00  457860.966667          2022-03-26
# 35 2022-03-26 16:13:00  457861.216667          2022-03-26
# 36 2022-03-27 12:02:00  457881.033333          2022-04-26
# 37 2022-03-28 15:30:00  457908.500000          2022-04-26
# 38 2022-03-31 14:15:00  457979.250000          2022-04-26

# %%
##testing the get_day_26_mapping
test_date = pd.Series(['2020-04-27 09:30'])
# Convert the underlying data to datetime 
test_date = pd.to_datetime(test_date)


print("2020-04-27 09:30 maps to:",get_day_26_mapping(test_date)[0])

test_date = pd.Series(['2020-04-24 23:30'])
# Convert the underlying data to datetime 
test_date = pd.to_datetime(test_date)

print("2020-04-24 23:30 maps to:",get_day_26_mapping(test_date)[0])
# Out:
# 2020-04-27 09:30 maps to: 2020-05-26 00:00:00
# 2020-04-24 23:30 maps to: 2020-04-26 00:00:00

# %%
X_train = np.reshape(X,(-1, 1))
Y_train = np.reshape(Y,(-1, 1))


_ = plt.plot(X_train, Y_train, "kx", mew=2)

# %%
k = gpflow.kernels.RBF()

# %%
m = gpflow.models.GPR(data=(X_train, Y_train), kernel=k, mean_function=None)

# %%
opt = gpflow.optimizers.Scipy()
opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=10000))

# %%
print_summary(m)
# Out:
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═══════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │     value │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═══════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 24825.8   │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │   110.365 │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │ 30052.9   │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═══════════╛

# %%
#creating testing data
last_trans = X.numpy().max()

# mapping the last date of transaction to day_26_mapping_date column to get day 26
day_26 = df[last_trans== df["unix_date"]]['day_26_mapping_date']

print("Our last transction", pd.to_datetime(df[last_trans == df["unix_date"]]['date'].values[0]))
print("The nearest day 26 is:", pd.to_datetime(day_26.values[0]))

# converting day_26 to the summation appraoch
day_26_sum = day_26.dt.year+day_26.dt.month+day_26.dt.day+ 23 + 59 +59

# converting day_26 to the to unix timestamp
day_26_unix_time = datetime.timestamp(pd.to_datetime(day_26.values[0]))/3600

print("day_26 if we use the SUM appraoch: ",day_26_sum.values[0])
print("day_26 if we use the unix_time appraoch: ",day_26_unix_time)

#generates points from the first transaction till  the nearst day 26 of the last transaction
X_test = np.linspace(X.numpy().min(), day_26_unix_time , 100).reshape(100, 1) #doxum
# Out:
# Our last transction 2022-12-03 17:10:00
# The nearest day 26 is: 2022-12-26 00:00:00
# day_26 if we use the SUM appraoch:  2201
# day_26 if we use the unix_time appraoch:  464445.0

# %%
# get the day in the last transaction X.iloc[-1]['date']
# Day_26 = day in last trans + ( day in last trans - 26 )
#In the system we should take Y= X(Day_26) #I explained in the code how to calculate Day_26
Day_26 = X[-1] + ( X[-1] - 26 )
Day_26
# Out:
# <tf.Tensor: shape=(1,), dtype=float64, numpy=array([915932.5])>

# %%
#generate test points for prediction
#predict mean and variance of latent GP at test points
mean, var = m.predict_f(X_test)

#generate 10 samples from posterior
tf.random.set_seed(1)  # for reproducibility
samples = m.predict_f_samples(X_test, 10)  # shape (10, 100, 1)
#plot
plt.figure(figsize=(12, 6))
plt.plot(X_train, Y_train, "kx", mew=2)
plt.plot(X_test, mean, "C0", lw=2)
plt.fill_between(
    X_test[:, 0],
    mean[:, 0] - 1.96 * np.sqrt(var[:, 0]),
    mean[:, 0] + 1.96 * np.sqrt(var[:, 0]),
    color="C0",
    alpha=0.2,
)
_=plt.plot(X_test, samples[:, :, 0].numpy().T, "C0", linewidth=0.5)

# %%
#sum of prdedicted points
mean.numpy().sum()
# Out:
# -2308.5279171823495

# %%
#mean of prdedicted points
mean.numpy().mean()
# Out:
# -23.085279171823494

# %%
#the value of last point (aka day 26 23:59:59)
print(mean.numpy()[-1][0])
# Out:
# -8.633336079084321e-05

# %%
import pickle
pickle.dump(m, open('gp_model.pkl', 'wb'))
