# %%
import gpflow
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from gpflow.utilities import print_summary
import pandas as pd
import numpy as np
from datetime import datetime
import time
from firebase_admin import credentials
from firebase_admin import firestore
import firebase_admin
import pandas as pd
import json
# The lines below are specific to the notebook format
# %matplotlib inline
plt.rcParams["figure.figsize"] = (12, 6)

# %% [markdown]
# ## Read the data from the firebase

# %%
import firebase_admin
from firebase_admin import credentials

if not firebase_admin._apps:
    cred = credentials.Certificate('sim1-ac95f-firebase-adminsdk-3hy48-80b6b88451.json') 
    default_app = firebase_admin.initialize_app(cred)


# firebase_admin.initialize_app(credential=None, options=None, name='[DEFAULT]')

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="sim1-ac95f-firebase-adminsdk-3hy48-80b6b88451.json"
cred = r"sim1-ac95f-firebase-adminsdk-3hy48-80b6b88451.json"
login = credentials.Certificate(cred)

# %%
db = firestore.client()
transaction = db.collection("transaction").stream()

# %%
dict_users = {"userid":[],"type":[], "amount":[],"time":[],"date":[]}
# data_items = data_dict.items()
# data_list = list(data_items)

count=0
for trans in transaction:
#     print(json.loads("{}".format(trans.to_dict())))

    us = json.loads(str(trans.to_dict()).replace("'",'"').replace(" ","").lower())
    print(us)
    dict_users["userid"].append(us["userid"])
    dict_users["type"].append(us["type"])
    dict_users["amount"].append(us["amount"])
    dict_users["time"].append(us["time"])
    dict_users["date"].append(us["date"])
# Out:
# {'time': '17:34', 'type': 'withdrawal', 'userid': 'ej19nxkmhmmlmjglcmdp9ffkrsb2', 'epochtime': 1666026255658, 'date': '22/10/2022', 'amount': '24'}
# {'type': 'withdrawal', 'amount': '2.00', 'time': '00:12', 'epochtime': 1666970507865, 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'date': '29/10/2022'}
# {'time': '19:06', 'type': 'withdrawal', 'amount': '100', 'userid': 'ej19nxkmhmmlmjglcmdp9ffkrsb2', 'date': '19/10/2022', 'epochtime': 1665947952296}
# {'date': '09/03/2022', 'amount': '16.00', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'type': 'withdrawal', 'time': '20:59', 'epochtime': 1646848821631}
# {'date': '26/10/2022', 'time': '18:59', 'amount': '67.00', 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'epochtime': 1666800019170, 'type': 'withdrawal'}
# {'type': 'سحب', 'epochtime': 1646848821631, 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'time': '20:59', 'date': '09/03/2022', 'amount': '16.00'}
# {'date': '21/03/2022', 'amount': '100.00', 'type': 'withdrawal', 'time': '03:00', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'epochtime': 1647820738423}
# {'epochtime': 1646848648726, 'time': '20:55', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'date': '09/03/2022', 'amount': '1.00', 'type': 'deposit'}
# {'type': 'deposit', 'epochtime': 1666851436088, 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'date': '27/10/2022', 'amount': '2.00', 'time': '12:56'}
# {'epochtime': 1646848821631, 'date': '09/03/2022', 'userid': 'ej19nxkmhmmlmjglcmdp9ffkrsb2', 'amount': '16.00', 'type': 'withdrawal', 'time': '20:59'}
# {'date': '28/10/2022', 'type': 'withdrawal', 'amount': '1.00', 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'time': '18:15', 'epochtime': 1666865425537}
# {'time': '20:54', 'type': 'withdrawal', 'date': '09/03/2022', 'epochtime': 1646848583704, 'amount': '1.00', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2'}
# {'type': 'withdrawal', 'time': '22:40', 'date': '14/10/2022', 'amount': '64.62', 'epochtime': 1665780036408, 'userid': 'ej19nxkmhmmlmjglcmdp9ffkrsb2'}
# {'time': '23:51', 'amount': '2.00', 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'date': '28/10/2022', 'epochtime': 1666970117081, 'type': 'withdrawal'}
# {'date': '09/03/2022', 'amount': '1.00', 'epochtime': 1646848583704, 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'type': 'withdrawal', 'time': '20:54'}
# {'amount': '1.00', 'type': 'سحب', 'date': '09/03/2022', 'time': '20:54', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'epochtime': 1646848583704}
# {'type': 'withdrawal', 'time': '20:54', 'epochtime': 1646848583704, 'date': '09/03/2022', 'amount': '1.00', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2'}
# {'time': '00:00', 'epochtime': 1666971206235, 'date': '30/10/2022', 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 
userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'epochtime': 1646848648726, 'type': 'deposit', 'date': '09/03/2022', 'amount': '1.00', 'time': '20:55'}
# {'time': '23:20', 'epochtime': 1666965642578, 'date': '28/10/2022', 'amount': '2.00', 'userid': 'glverta4jrmfwcjtqwumqwcy0ne2', 'type': 'withdrawal'}
# {'time': '20:54', 'date': '09/03/2022', 'type': 'withdrawal', 'userid': 'fu6zb2intjubs3kwdd6p9zmaplx2', 'epochtime': 1646848583704, 'amount': '1.00'}
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-60e2208c98aa> in <module>
#       7 #     print(json.loads("{}".format(trans.to_dict())))
#       8
# ----> 9     us = json.loads(str(trans.to_dict()).replace("'",'"').replace(" ","").lower())
#      10     print(us)
#      11     dict_users["userid"].append(us["userid"])
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 23 (char 22)

# %%
df = pd.DataFrame.from_dict(dict_users)
df = df[df["userid"]=="EJ19NxkmHMMLMJgLcMdP9FfKRSb2"]

df["date"] = pd.to_datetime(df['date']+" "+df["time"],errors='coerce')
df["amount"] = df["amount"].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userid  0 non-null      object
#  1   type    0 non-null      object
#  2   amount  0 non-null      float64
#  3   time    0 non-null      object
#  4   date    0 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 0.0+ bytes

# %% [markdown]
# ## Hnadling outliers

# %%
df
# Out:
# Empty DataFrame
# Columns: [userid, type, amount, time, date]
# Index: []

# %%
df['amount'] = tf.cast(df['amount'], tf.float64)
condition = df["type"] == 'withdrawal'
#df.loc[condition, ['amount']] *= -1

print(df)
for x in ["amount"]:
    q75,q25 = np.percentile(df.loc[:,x],[75,25])
    intr_qr = q75-q25

    max = q75+(1.5*intr_qr)
    min = q25-(1.5*intr_qr)

    df.loc[df[x] < min,x] = np.nan
    df.loc[df[x] > max,x] = np.nan
df = df.dropna(axis = 0)
df
# Out:
# Empty DataFrame
# Columns: [index, userid, type, amount, time, date]
# Index: []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-89450e597b2f> in <module>
#       5 print(df)
#       6 for x in ["amount"]:
# ----> 7     q75,q25 = np.percentile(df.loc[:,x],[75,25])
#       8     intr_qr = q75-q25
#       9
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3816     if not _quantile_is_valid(q):
#    3817         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3818     return _quantile_unchecked(
#    3819         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3820
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3935                         interpolation='linear', keepdims=False):
#    3936     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 3937     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3938                     overwrite_input=overwrite_input,
#    3939                     interpolation=interpolation)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3513         keepdim = (1,) * a.ndim
#    3514
# -> 3515     r = func(a, **kwargs)
#    3516     return r, keepdim
#    3517
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in _quantile_ureduce_func(***failed resolving arguments***)
#    4048                 indices_below.ravel(), indices_above.ravel(), [-1]
#    4049             )), axis=0)
# -> 4050             n = np.isnan(ap[-1])
#    4051         else:
#    4052             # cannot contain nan
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
#suggsted appraoch converting to unix timestamp
df["unix_date"] = [datetime.timestamp(dt)/3600 for dt in df["date"]]
df["unix_date"] =tf.cast(df["unix_date"] , tf.float64)
X = df[["unix_date"]]
X = tf.cast(X, tf.float64)

# %%
Y = df[['amount']]
Y = tf.cast(Y, tf.float64)

# %%
#Create a mapping date for example if the date was 24/04/2022 the day26 that should be mapped to 26/04/2020
#27/04/2020 the day26 that should be mapped is 26/05/2020
#this will help us in creating the X_test see the cell bellow were I created X_test
def get_day_26_mapping(date):
    import datetime
    new_date = []
    for m,d,y in zip(date.dt.month,date.dt.day,date.dt.year):
        #print(m,d,y)
        new_d = 0
        new_m = 0
        new_y = 0
        if d<=26:
            new_d = 26
            new_m = m
            new_y = y
        else:
            new_d = 26
            if m+1>12:
                new_d = 26
                new_m = 1
                new_y = y + 1
            else:
                new_d = 26
                new_m = m + 1
                new_y = y
        new_date.append(datetime.datetime(new_y,new_m,new_d))
    return new_date

df['day_26_mapping_date'] = get_day_26_mapping(df['date'])
df
# Out:
#     index                        userid        type  amount   time  \
# 0       0  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    68.0  08:00
# 1       1  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    37.0  09:21
# 2       4  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    77.0  12:55
# 3       5  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     7.0  07:59
# 4       6  ej19nxkmhmmlmjglcmdp9ffkrsb2     deposit    30.0  17:33
# 5       7  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    18.0  17:24
# 6       8  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    13.0  11:05
# 7       9  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    18.0  15:09
# 8      10  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    24.0  07:45
# 9      11  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    26.0  07:30
# 10     12  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    45.0  17:36
# 11     13  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    74.0  04:42
# 12     14  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     1.0  11:01
# 13     17  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    20.0  09:17
# 14     18  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    45.0  10:06
# 15     19  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    63.0  20:58
# 16     21  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    18.0  09:22
# 17     22  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    17.0  12:35
# 18     23  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    51.0  07:51
# 19     24  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    27.0  10:30
# 20     25  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal   100.0  09:20
# 21     26  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    10.0  10:17
# 22     27  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    58.0  10:53
# 23     28  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    26.0  10:55
# 24     29  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     3.0  11:02
# 25     30  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     3.0  10:57
# 26     31  ej19nxkmhmmlmjglcmdp9ffkrsb2     deposit   100.0  07:23
# 27     32  ej19nxkmhmmlmjglcmdp9ffkrsb2     deposit   100.0  09:46
# 28     33  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    50.0  16:01
# 29     34  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    27.0  09:15
# 30     35  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    10.0  11:01
# 31     36  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     9.0  09:56
# 32     37  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal   100.0  11:09
# 33     38  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    53.0  16:37
# 34     39  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    21.0  11:17
# 35     40  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    18.0  07:47
# 36     42  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    35.0  11:48
# 37     44  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    40.0  10:56
# 38     45  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     3.0  09:22
# 39     47  ej19nxkmhmmlmjglcmdp9ffkrsb2     deposit   100.0  11:05
# 40     48  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     4.0  07:55
# 41     49  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    93.0  10:30
# 42     50  ej19nxkmhmmlmjglcmdp9ffkrsb2     deposit   100.0  07:52
# 43     52  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    13.0  10:45
# 44     53  ej19nxkmhmmlmjglcmdp9ffkrsb2     deposit    55.0  09:20
# 45     54  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    77.0  00:08
# 46     55  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     1.0  10:56
# 47     56  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     4.0  07:56
# 48     57  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    28.0  17:20
# 49     59  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    34.0  07:54
# 50     60  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    16.0  16:48
# 51     61  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal     1.0  17:23
# 52     62  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal   100.0  07:27
# 53     64  ej19nxkmhmmlmjglcmdp9ffkrsb2  withdrawal    27.0  10:12
#
#                   date      unix_date day_26_mapping_date
# 0  2022-12-09 08:00:00  464045.000000          2022-12-26
# 1  2022-08-09 09:21:00  461118.350000          2022-08-26
# 2  2022-09-23 12:55:00  462201.916667          2022-09-26
# 3  2022-09-13 07:59:00  461956.983333          2022-09-26
# 4  2022-09-16 17:33:00  462038.550000          2022-09-26
# 5  2022-09-16 17:24:00  462038.400000          2022-09-26
# 6  2022-09-18 11:05:00  462080.083333          2022-09-26
# 7  2022-09-18 15:09:00  462084.150000          2022-09-26
# 8  2022-09-15 07:45:00  462004.750000          2022-09-26
# Out:
# 2020-04-27 09:30 maps to: 2020-05-26 00:00:00
# 2020-04-24 23:30 maps to: 2020-04-26 00:00:00

# %%
X_train = np.reshape(X,(-1, 1))
Y_train = np.reshape(Y,(-1, 1))
print(len(Y_train))

_ = plt.plot(X_train, Y_train, "kx", mew=2)
# Out:
# 54

# %%
k = gpflow.kernels.RBF()

# %%
m = gpflow.models.GPR(data=(X_train, Y_train), kernel=k, mean_function=None)

# %%
opt = gpflow.optimizers.Scipy()
opt_logs = opt.minimize(m.training_loss, m.trainable_variables, options=dict(maxiter=10000))

# %%
print_summary(m)
# Out:
# ╒═════════════════════════╤═══════════╤══════════════════╤═════════╤═════════════╤═════════╤═════════╤═══════════╕
# │ name                    │ class     │ transform        │ prior   │ trainable   │ shape   │ dtype   │     value │
# ╞═════════════════════════╪═══════════╪══════════════════╪═════════╪═════════════╪═════════╪═════════╪═══════════╡
# │ GPR.kernel.variance     │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │ 2255.47   │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.kernel.lengthscales │ Parameter │ Softplus         │         │ True        │ ()      │ float64 │   56.9973 │
# ├─────────────────────────┼───────────┼──────────────────┼─────────┼─────────────┼─────────┼─────────┼───────────┤
# │ GPR.likelihood.variance │ Parameter │ Softplus + Shift │         │ True        │ ()      │ float64 │  533.757  │
# ╘═════════════════════════╧═══════════╧══════════════════╧═════════╧═════════════╧═════════╧═════════╧═══════════╛

# %%
#creating testing data
last_trans = X.numpy().max()

# mapping the last date of transaction to day_26_mapping_date column to get day 26
day_26 = df[last_trans== df["unix_date"]]['day_26_mapping_date']

print("Our last transction", pd.to_datetime(df[last_trans == df["unix_date"]]['date'].values[0]))
print("The nearest day 26 is:", pd.to_datetime(day_26.values[0]))

# converting day_26 to the summation appraoch
day_26_sum = day_26.dt.year+day_26.dt.month+day_26.dt.day+ 23 + 59 +59

# converting day_26 to the to unix timestamp
day_26_unix_time = datetime.timestamp(pd.to_datetime(day_26.values[0]))/3600

print("day_26 if we use the SUM appraoch: ",day_26_sum.values[0])
print("day_26 if we use the unix_time appraoch: ",day_26_unix_time)

#generates points from the first transaction till  the nearst day 26 of the last transaction
X_test = np.linspace(X.numpy().min(), day_26_unix_time , 100).reshape(100, 1) #doxum
# Out:
# Our last transction 2022-12-09 16:48:00
# The nearest day 26 is: 2022-12-26 00:00:00
# day_26 if we use the SUM appraoch:  2201
# day_26 if we use the unix_time appraoch:  464445.0

# %%
# get the day in the last transaction X.iloc[-1]['date']
# Day_26 = day in last trans + ( day in last trans - 26 )
#In the system we should take Y= X(Day_26) #I explained in the code how to calculate Day_26
Day_26 = X[-1] + ( X[-1] - 26 )
Day_26
# Out:
# <tf.Tensor: shape=(1,), dtype=float64, numpy=array([924084.4])>

# %%
#generate test points for prediction
#predict mean and variance of latent GP at test points
mean, var = m.predict_f(X_test)

#generate 10 samples from posterior
tf.random.set_seed(1)  # for reproducibility
samples = m.predict_f_samples(X_test, 2)  # shape (10, 100, 1)
#plot
plt.figure(figsize=(12, 6))
plt.plot(X_train, Y_train, "kx", mew=2)
plt.plot(X_test, mean, "C0", lw=2)
plt.fill_between(
    X_test[:, 0],
    mean[:, 0] - 1.96 * np.sqrt(var[:, 0]),
    mean[:, 0] + 1.96 * np.sqrt(var[:, 0]),
    color="C0",
    alpha=0.2,
)
#_=plt.plot(X_test, samples[:, :, 0].numpy().T, "C0", linewidth=0.5)

# %%
#sum of prdedicted points
mean.numpy().sum()
# Out:
# 1030.3785452185155

# %%
#mean of prdedicted points
mean.numpy().mean()
# Out:
# 10.303785452185155

# %%
#the value of last point (aka day 26 23:59:59)
print(mean.numpy()[-1][0])
# Out:
# -2.5631837002085068e-09

# %%
import pickle
pickle.dump(m, open('gp_model.pkl', 'wb'))
